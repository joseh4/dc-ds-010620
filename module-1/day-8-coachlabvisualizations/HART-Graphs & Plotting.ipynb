# %%
import matplotlib.pyplot as plt
# %matplotlib notebook
import pandas as pd
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv('cleaned_titanic.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare  youngin  male  \
# 0            1         0       3  22.0      1      0   7.2500        0     1
# 1            2         1       1  38.0      1      0  71.2833        0     0
# 2            3         1       3  26.0      0      0   7.9250        0     0
# 3            4         1       1  35.0      1      0  53.1000        0     0
# 4            5         0       3  35.0      0      0   8.0500        0     1
#
#    Q  S
# 0  0  1
# 1  0  0
# 2  0  1
# 3  0  1
# 4  0  1

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   889.000000  889.000000  889.000000  889.000000  889.000000
# mean    446.000000    0.382452    2.311586   29.019314    0.524184
# std     256.998173    0.486260    0.834700   13.209814    1.103705
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     224.000000    0.000000    2.000000   22.000000    0.000000
# 50%     446.000000    0.000000    3.000000   26.000000    0.000000
# 75%     668.000000    1.000000    3.000000   36.500000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare     youngin        male           Q           S
# count  889.000000  889.000000  889.000000  889.000000  889.000000  889.000000
# mean     0.382452   32.096681    0.069741    0.649044    0.086614    0.724409
# std      0.806761   49.697504    0.254854    0.477538    0.281427    0.447063
# ...

# %%
fig = plt.figure(figsize=(18,10))  # create a plot figure
x = np.linspace(0, 10, 100)

# create the first of two panels and set current axis
plt.subplot(2, 3, 1) # (rows, columns, panel number)
plt.plot(x, np.sin(x),label='name for it goes here') # label names the legend
plt.legend(loc='lower left') # Got this from the documentation... shift + tab
plt.title('Sin')
# create the second panel and set current axis

plt.subplot(2, 3, 2)
plt.plot(x, np.cos(x),label='Cos');
plt.legend()
plt.title('Cos')

plt.subplot(2, 3, 3)
plt.plot(x,np.tan(x),label='Tan')
plt.legend()
plt.title('Tan')
# Out:
# Text(0.5, 1.0, 'Tan')

# %%
plt.hist(df['Fare'], bins=30,density=False)
plt.xlabel('Fare')
plt.ylabel('Fare')
# Out:
# Text(0, 0.5, 'Fare')

# %%
sns.kdeplot(data=df['Age'], shade=True)

# %%
for column in df:   # this for loop iterates thorugh every column and plots the figures
    plt.figure()
    df.boxplot([column]) # pandas has access to matplotlib commands

# %%
bplot=sns.boxplot(x='Fare', 
                 data=df, 
                 width=0.7,
                 palette="colorblind")
 
# add swarmplot
bplot=sns.swarmplot(x='Fare',
              data=df, 
              color='black',
              alpha=0.35)

# %%
sns.lmplot(x='Age',y='Fare',data=df)

# %%
import matplotlib
colorname = []
colorid = []
for name, hex in matplotlib.colors.cnames.items():
    colorname.append(name)
    colorid.append(hex)

# %%
zippedcolors = list(zip(colorname, colorid))
zippedcolors = sorted(zippedcolors, key=lambda x: x[1])

# %%
print(zippedcolors)
# Out:
# [('black', '#000000'), ('navy', '#000080'), ('darkblue', '#00008B'), ('mediumblue', '#0000CD'), ('blue', '#0000FF'), ('darkgreen', '#006400'), ('green', '#008000'), ('teal', '#008080'), ('darkcyan', '#008B8B'), ('deepskyblue', '#00BFFF'), ('darkturquoise', '#00CED1'), ('mediumspringgreen', '#00FA9A'), ('lime', '#00FF00'), ('springgreen', '#00FF7F'), ('aqua', '#00FFFF'), ('cyan', '#00FFFF'), ('midnightblue', '#191970'), ('dodgerblue', '#1E90FF'), ('lightseagreen', '#20B2AA'), ('forestgreen', '#228B22'), ('seagreen', '#2E8B57'), ('darkslategray', '#2F4F4F'), ('darkslategrey', '#2F4F4F'), ('limegreen', '#32CD32'), ('mediumseagreen', '#3CB371'), ('turquoise', '#40E0D0'), ('royalblue', '#4169E1'), ('steelblue', '#4682B4'), ('darkslateblue', '#483D8B'), ('mediumturquoise', '#48D1CC'), ('indigo', '#4B0082'), ('darkolivegreen', '#556B2F'), ('cadetblue', '#5F9EA0'), ('cornflowerblue', '#6495ED'), ('rebeccapurple', '#663399'), ('mediumaquamarine', '#66CDAA'), ('dimgray', '#696969'), ('dimgrey'
# ...

# %%
df.loc[df['Fare']== df['Fare'].max()]
# Out:
#      PassengerId  Survived  Pclass   Age  SibSp  Parch      Fare  youngin  \
# 257          259         1       1  35.0      0      0  512.3292        0
# 678          680         1       1  36.0      0      1  512.3292        0
# 736          738         1       1  35.0      0      0  512.3292        0
#
#      male  Q  S
# 257     0  0  0
# 678     1  0  0
# 736     1  0  0

# %%
barplot = plt.bar(df['Fare'],df['Age'], color = 'sandybrown', alpha = 0.85, label='dollars')
barplot[1].set_color('orchid')
plt.xlabel('Fare', fontsize = 15, weight = 'bold')
plt.ylabel('Age', fontsize = 15, weight = 'bold')
plt.title('Fare vs. Age', fontsize = 15, weight = 'bold')
plt.legend(loc='lower right')

# %% [markdown]
# >https://towardsdatascience.com/animations-with-matplotlib-d96375c5442c

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# Get the data (csv file is hosted on the web)
url = 'https://python-graph-gallery.com/wp-content/uploads/volcano.csv'
data = pd.read_csv(url)

# Transform it to a long format
df=data.unstack().reset_index()
df.columns=["X","Y","Z"]

# And transform the old column name in something numeric
df['X']=pd.Categorical(df['X'])
df['X']=df['X'].cat.codes

# We are going to do 20 plots, for 20 different angles
for angle in range(70,210,2):
# Make the plot
    fig = plt.figure()
    ax = fig.gca(projection='3d')
    ax.plot_trisurf(df['Y'], df['X'], df['Z'], cmap=plt.cm.viridis, linewidth=0.2)

    ax.view_init(30,angle)

    filename='Images/Volcano_step'+str(angle)+'.png'
    plt.savefig(filename, dpi=96)
    plt.gca()

# %%
from IPython.display import Image
Image(filename="./Images/animated_volcano.gif")
