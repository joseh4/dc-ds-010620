# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('bom.movie_gross.csv.gz')

# %%
# function for adding foreign gross and domestic gross totals for movies
def money(df):
    for index, row in df.iterrows():
            print('{} is the total for {}'.format(int(row['domestic_gross']) + int(row['foreign_gross']), row['title']))

# %%
money(df.head())
# Out:
# 1067000000 is the total for Toy Story 3
# 1025500000 is the total for Alice in Wonderland (2010)
# 960300000 is the total for Harry Potter and the Deathly Hallows Part 1
# 828300000 is the total for Inception
# 752600000 is the total for Shrek Forever After

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3387 entries, 0 to 3386
# Data columns (total 5 columns):
# title             3387 non-null object
# studio            3382 non-null object
# domestic_gross    3359 non-null float64
# foreign_gross     2037 non-null object
# year              3387 non-null int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 132.4+ KB

# %%
values = {'studio': 'NA', 'domestic_gross': 0, 'foreign_gross': 0}

# %%
df = df.fillna(value=values) # this is to fill NA values so I can add gross columns together for each movie

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3387 entries, 0 to 3386
# Data columns (total 5 columns):
# title             3387 non-null object
# studio            3387 non-null object
# domestic_gross    3387 non-null float64
# foreign_gross     3387 non-null object
# year              3387 non-null int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 132.4+ KB

# %%
df.loc[df['title'] == 'The Quake']
# Out:
#           title studio  domestic_gross foreign_gross  year
# 3382  The Quake  Magn.          6200.0             0  2018

# %%
df['foreign_gross'] = pd.to_numeric(df['foreign_gross'], errors = 'coerce')

# %%
df['foreign_gross']
# Out:
# 0       652000000.0
# 1       691300000.0
# 2       664300000.0
# 3       535700000.0
# 4       513900000.0
#            ...
# 3382            0.0
# 3383            0.0
# 3384            0.0
# 3385            0.0
# 3386            0.0
# Name: foreign_gross, Length: 3387, dtype: float64

# %%
index = df['foreign_gross'].index[df['foreign_gross'].apply(np.isnan)]

# %%
index
# Out:
# Int64Index([1872, 1873, 1874, 2760, 3079], dtype='int64')

# %%
dfobj = pd.DataFrame(df, columns = ['foreign_gross', 'title'], index = [1872, 1873, 1874, 2760, 3079])

# %%
dfobj
# Out:
#      foreign_gross                         title
# 1872       1,131.6  Star Wars: The Force Awakens
# 1873       1,019.4                Jurassic World
# 1874       1,163.0                     Furious 7
# 2760       1,010.0       The Fate of the Furious
# 3079       1,369.5        Avengers: Infinity War

# %%
df.at[1872, 'foreign_gross']
# Out:
# '1,131.6'

# %%
df.at[1872, 'foreign_gross'] = 1131600000

# %%
df.at[1872, 'foreign_gross']
# Out:
# 1131600000

# %%
df.loc[df['title'] == 'Star Wars: The Force Awakens']
# Out:
#                              title studio  domestic_gross foreign_gross  year
# 1872  Star Wars: The Force Awakens     BV     936700000.0    1131600000  2015

# %%
df.at[1873, 'foreign_gross'] = 1019400000

# %%
df.at[1874, 'foreign_gross'] = 1163000000

# %%
df.at[2760, 'foreign_gross'] = 1010000000

# %%
df.at[3079, 'foreign_gross'] = 1369500000

# %%
money(df.head())
# Out:
# 1067000000 is the total for Toy Story 3
# 1025500000 is the total for Alice in Wonderland (2010)
# 960300000 is the total for Harry Potter and the Deathly Hallows Part 1
# 828300000 is the total for Inception
# 752600000 is the total for Shrek Forever After

# %%
df['foreign_gross'] = df['foreign_gross'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3387 entries, 0 to 3386
# Data columns (total 5 columns):
# title             3387 non-null object
# studio            3387 non-null object
# domestic_gross    3387 non-null int64
# foreign_gross     3387 non-null int64
# year              3387 non-null int64
# dtypes: int64(3), object(2)
# memory usage: 132.4+ KB

# %%
df['total_gross'] = df['foreign_gross'] + df['domestic_gross']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3387 entries, 0 to 3386
# Data columns (total 6 columns):
# title             3387 non-null object
# studio            3387 non-null object
# domestic_gross    3387 non-null int64
# foreign_gross     3387 non-null int64
# year              3387 non-null int64
# total_gross       3387 non-null int64
# dtypes: int64(4), object(2)
# memory usage: 158.9+ KB

# %%
largest = [df['total_gross'].nlargest(10)]
# Out:
# [1872    2068300000
#  3079    2048300000
#  1873    1671700000
#  727     1518900000
#  1874    1516000000
#  1875    1405400000
#  3080    1347000000
#  328     1341500000
#  2758    1332600000
#  3081    1309500000
#  Name: total_gross, dtype: int64]

# %%
df.loc[[1872, 3079, 1873, 727, 1874, 1875, 3080, 328, 2758, 3081]]
# Out:
#                                             title studio  domestic_gross  \
# 1872                 Star Wars: The Force Awakens     BV       936700000
# 3079                       Avengers: Infinity War     BV       678800000
# 1873                               Jurassic World   Uni.       652300000
# 727                         Marvel's The Avengers     BV       623400000
# 1874                                    Furious 7   Uni.       353000000
# 1875                      Avengers: Age of Ultron     BV       459000000
# 3080                                Black Panther     BV       700100000
# 328   Harry Potter and the Deathly Hallows Part 2     WB       381000000
# 2758                     Star Wars: The Last Jedi     BV       620200000
# 3081               Jurassic World: Fallen Kingdom   Uni.       417700000
#
#       foreign_gross  year  total_gross
# 1872     1131600000  2015   2068300000
# 3079     1369500000  2018   2048300000
# 1873     1019400000  2015   1671700000
# 727       895500000  2012   1518900000
# 1874     1163000000  2015   1516000000
# 1875      946400000  2015   1405400000
# 3080      646900000  2018   1347000000
# 328       960500000  2011   1341500000
# 2758      712400000  2017   1332600000
# 3081      891800000  2018   1309500000

# %%
#drop all columns but title and total_gross and retrieve the first 100 most grossed movies
new_df = df.drop(['studio', 'domestic_gross', 'foreign_gross', 'year'], axis = 1)

# %%
first_50_most_profittable = new_df.nlargest(50, columns = 'total_gross')
first_50_most_profittable.head()
# Out:
#                              title  total_gross
# 1872  Star Wars: The Force Awakens   2068300000
# 3079        Avengers: Infinity War   2048300000
# 1873                Jurassic World   1671700000
# 727          Marvel's The Avengers   1518900000
# 1874                     Furious 7   1516000000

# %%
first_1000_most_profittable = new_df.nlargest(1000, columns = 'total_gross')
first_1000_most_profittable
# Out:
#                                       title  total_gross
# 1872           Star Wars: The Force Awakens   2068300000
# 3079                 Avengers: Infinity War   2048300000
# 1873                         Jurassic World   1671700000
# 727                   Marvel's The Avengers   1518900000
# 1874                              Furious 7   1516000000
# ...                                     ...          ...
# 1587                                 Oculus     44000000
# 1982                             Max (2015)     44000000
# 1983                            Still Alice     43900000
# 2439                           Cafe Society     43800000
# 114   The Girl Who Kicked the Hornet's Nest     43500000
#
# [1000 rows x 2 columns]

# %%
movies = pd.read_csv('imdb.title.basics.csv.gz')
new_movies = movies
new_movies = new_movies.drop(columns = ['original_title', 'runtime_minutes', 'start_year', 'tconst'])
new_movies.rename(columns = {'primary_title':'title'}, inplace = True)

# %%
two_tables = pd.merge(first_100_most_profittable, new_movies, on = 'title', how = 'inner')
# drop unnecessary columns
# combined_table = combined_table.drop(columns = ['Unnamed: 0', 'id', 'original_language', 'release_date', 'vote_average', 'vote_count'])
two_tables
# Out:
#                         title  total_gross                   genres
# 0      Avengers: Infinity War   2048300000  Action,Adventure,Sci-Fi
# 1              Jurassic World   1671700000  Action,Adventure,Sci-Fi
# 2                   Furious 7   1516000000    Action,Crime,Thriller
# 3     Avengers: Age of Ultron   1405400000  Action,Adventure,Sci-Fi
# 4               Black Panther   1347000000  Action,Adventure,Sci-Fi
# ...                       ...          ...                      ...
# 1023                  Boyhood     44500000                    Drama
# 1024           47 Meters Down     44300000   Adventure,Drama,Horror
# 1025                  Machete     44100000    Action,Crime,Thriller
# 1026                   Oculus     44000000           Horror,Mystery
# 1027              Still Alice     43900000                    Drama
#
# [1028 rows x 3 columns]

# %%
two_tables.loc[two_tables['title'] == 'John Wick']
# Out:
#          title  total_gross                 genres
# 713  John Wick     88700000  Action,Crime,Thriller

# %%
first_100_most_profittable.loc[first_100_most_profittable['title'] == 'John Wick']
# Out:
#           title  total_gross
# 1552  John Wick     88700000

# %%
popularity = pd.read_csv('tmdb.movies.csv.gz')
popularity = popularity.drop(columns = ['Unnamed: 0','genre_ids','id','original_language','original_title','release_date','vote_average','vote_count'])
popularity
# Out:
#        popularity                                         title
# 0          33.533  Harry Potter and the Deathly Hallows: Part 1
# 1          28.734                      How to Train Your Dragon
# 2          28.515                                    Iron Man 2
# 3          28.005                                     Toy Story
# 4          27.920                                     Inception
# ...           ...                                           ...
# 26512       0.600                         Laboratory Conditions
# 26513       0.600                               _EXHIBIT_84xxx_
# 26514       0.600                                  The Last One
# 26515       0.600                                  Trailer Made
# 26516       0.600                                    The Church
#
# [26517 rows x 2 columns]

# %%
combined_data = pd.merge(two_tables, popularity, on = 'title', how = 'inner')
combined_data.nlargest(10, 'popularity')
# Out:
#                                            title  total_gross  \
# 0                         Avengers: Infinity War   2048300000
# 876                                    John Wick     88700000
# 37     The Hobbit: The Battle of the Five Armies    956000000
# 83                       Guardians of the Galaxy    773400000
# 353                            Blade Runner 2049    259300000
# 354                            Blade Runner 2049    259300000
# 111  Fantastic Beasts: The Crimes of Grindelwald    653700000
# 154                    Ralph Breaks the Internet    529200000
# 41                        Spider-Man: Homecoming    880200000
# 124                         Ant-Man and the Wasp    622600000
#
#                          genres  popularity
# 0       Action,Adventure,Sci-Fi      80.773
# 876       Action,Crime,Thriller      78.123
# 37            Adventure,Fantasy      53.783
# 83      Action,Adventure,Comedy      49.606
# 353        Drama,Mystery,Sci-Fi      48.571
# 354        Drama,Mystery,Sci-Fi      48.571
# 111    Adventure,Family,Fantasy      48.508
# 154  Adventure,Animation,Comedy      48.057
# 41      Action,Adventure,Sci-Fi      46.775
# 124     Action,Adventure,Comedy      44.729

# %%
test_data = combined_data

# %%
test_data.loc[test_data['title'] == 'Black Panther']
# Out:
#            title  total_gross                   genres  popularity
# 4  Black Panther   1347000000  Action,Adventure,Sci-Fi       2.058
# 5  Black Panther   1347000000  Action,Adventure,Sci-Fi      44.140

# %%
test_data.nlargest(50, columns = 'popularity')
# Out:
#                                             title  total_gross  \
# 0                          Avengers: Infinity War   2048300000
# 876                                     John Wick     88700000
# 37      The Hobbit: The Battle of the Five Armies    956000000
# 83                        Guardians of the Galaxy    773400000
# 353                             Blade Runner 2049    259300000
# 354                             Blade Runner 2049    259300000
# 111   Fantastic Beasts: The Crimes of Grindelwald    653700000
# 154                     Ralph Breaks the Internet    529200000
# 41                         Spider-Man: Homecoming    880200000
# 124                          Ant-Man and the Wasp    622600000
# 3                         Avengers: Age of Ultron   1405400000
# 5                                   Black Panther   1347000000
# 63                                 Thor: Ragnarok    854000000
# 64                                 Thor: Ragnarok    854000000
# 170                                     Bumblebee    468000000
# 88                     X-Men: Days of Future Past    747800000
# 46                 Guardians of the Galaxy Vol. 2    863700000
# 912                                Mortal Engines     83700000
# 258                                    Robin Hood    321700000
# 261                                    Robin Hood    321700000
# 264                                    Robin Hood    321700000
# 267                                    Robin Hood    321700000
# 270                                    Robin Hood    321700000
# 142                             X-Men: Apocalypse    543900000
# 19                     Captain America: Civil War   1153300000
# 82                                     Deadpool 2    779000000
# 20                                        Aquaman   1147800000
# 175                                          Thor    449300000
# 38                              Bohemian Rhapsody    903600000
# 236                               The Maze Runner    348300000
# 109                                    Big Hero 6    657800000
# 110                                    Big Hero 6    657800000
# 15                                  Incredibles 2   1242800000
# 272                                    Green Book    319800000
# 81                                       Deadpool    783100000
# 8                  Jurassic World: Fallen Kingdom   1309500000
# 107                                Justice League    657900000
# 108                                Justice League    657900000
# 6                        Star Wars: The Last Jedi   1332600000
# 7                        Star Wars: The Last Jedi   1332600000
# 86          The Hunger Games: Mockingjay - Part 1    755300000
# 517                                      The Mule    172500000
# 519                                      The Mule    172500000
# 521                                      The Mule    172500000
# 396                            The Imitation Game    233500000
# 102                                Doctor Strange    677700000
# 103                                Doctor Strange    677700000
# 159                                       Ant-Man    519300000
# 1155                                   Peppermint     53800000
# 130                          The Hangover Part II    586800000
#
#                           genres  popularity
# 0        Action,Adventure,Sci-Fi      80.773
# 876        Action,Crime,Thriller      78.123
# 37             Adventure,Fantasy      53.783
# 83       Action,Adventure,Comedy      49.606
# 353         Drama,Mystery,Sci-Fi      48.571
# 354         Drama,Mystery,Sci-Fi      48.571
# 111     Adventure,Family,Fantasy      48.508
# 154   Adventure,Animation,Comedy      48.057
# 41       Action,Adventure,Sci-Fi      46.775
# 124      Action,Adventure,Comedy      44.729
# 3        Action,Adventure,Sci-Fi      44.383
# 5        Action,Adventure,Sci-Fi      44.140
# 63       Action,Adventure,Comedy      43.450
# 64       Action,Adventure,Comedy      43.450
# 170      Action,Adventure,Sci-Fi      43.078
# 88       Action,Adventure,Sci-Fi      41.867
# 46       Action,Adventure,Comedy      40.228
# 912     Action,Adventure,Fantasy      40.095
# 258       Action,Adventure,Drama      39.975
# 261                 Action,Drama      39.975
# 264    Action,Adventure,Thriller      39.975
# 267                          NaN      39.975
# 270     Action,Adventure,History      39.975
# 142      Action,Adventure,Sci-Fi      39.293
# 19       Action,Adventure,Sci-Fi      39.137
# 82       Action,Adventure,Comedy      38.894
# 20      Action,Adventure,Fantasy      38.102
# 175     Action,Adventure,Fantasy      38.068
# 38         Biography,Drama,Music      37.197
# 236        Action,Mystery,Sci-Fi      36.955
# 109   Action,Adventure,Animation      36.920
# 110   Action,Adventure,Animation      36.920
# 15    Action,Adventure,Animation      36.286
# 272       Biography,Comedy,Drama      36.284
# 81       Action,Adventure,Comedy      35.067
# 8        Action,Adventure,Sci-Fi      34.958
# 107     Action,Adventure,Fantasy      34.953
# 108     Action,Adventure,Fantasy      34.953
# 6       Action,Adventure,Fantasy      34.293
# 7       Action,Adventure,Fantasy      34.293
# 86       Action,Adventure,Sci-Fi      33.837
# 517                 Comedy,Drama      33.830
# 519           Comedy,Crime,Drama      33.830
# 521         Crime,Drama,Thriller      33.830
# 396     Biography,Drama,Thriller      33.078
# 102     Action,Adventure,Fantasy      33.035
# 103     Action,Adventure,Fantasy      33.035
# 159      Action,Adventure,Comedy      32.715
# 1155          Action,Crime,Drama      32.476
# 130               Comedy,Mystery      32.266

# %%
test_data['title'] = test_data.title.drop_duplicates(keep = 'last')

# %%
test_data.nlargest(20, columns = 'popularity')
# Out:
#                                            title  total_gross  \
# 0                         Avengers: Infinity War   2048300000
# 876                                    John Wick     88700000
# 37     The Hobbit: The Battle of the Five Armies    956000000
# 83                       Guardians of the Galaxy    773400000
# 353                                          NaN    259300000
# 354                            Blade Runner 2049    259300000
# 111  Fantastic Beasts: The Crimes of Grindelwald    653700000
# 154                    Ralph Breaks the Internet    529200000
# 41                        Spider-Man: Homecoming    880200000
# 124                         Ant-Man and the Wasp    622600000
# 3                        Avengers: Age of Ultron   1405400000
# 5                                  Black Panther   1347000000
# 63                                           NaN    854000000
# 64                                Thor: Ragnarok    854000000
# 170                                    Bumblebee    468000000
# 88                    X-Men: Days of Future Past    747800000
# 46                Guardians of the Galaxy Vol. 2    863700000
# 912                               Mortal Engines     83700000
# 258                                          NaN    321700000
# 261                                          NaN    321700000
#
#                          genres  popularity
# 0       Action,Adventure,Sci-Fi      80.773
# 876       Action,Crime,Thriller      78.123
# 37            Adventure,Fantasy      53.783
# 83      Action,Adventure,Comedy      49.606
# 353        Drama,Mystery,Sci-Fi      48.571
# 354        Drama,Mystery,Sci-Fi      48.571
# 111    Adventure,Family,Fantasy      48.508
# 154  Adventure,Animation,Comedy      48.057
# 41      Action,Adventure,Sci-Fi      46.775
# 124     Action,Adventure,Comedy      44.729
# 3       Action,Adventure,Sci-Fi      44.383
# 5       Action,Adventure,Sci-Fi      44.140
# 63      Action,Adventure,Comedy      43.450
# 64      Action,Adventure,Comedy      43.450
# 170     Action,Adventure,Sci-Fi      43.078
# 88      Action,Adventure,Sci-Fi      41.867
# 46      Action,Adventure,Comedy      40.228
# 912    Action,Adventure,Fantasy      40.095
# 258      Action,Adventure,Drama      39.975
# 261                Action,Drama      39.975

# %%
test_data = test_data.dropna(subset = ['title'], axis = 0, how = 'any')

# %%
test_data.isna().sum()
# Out:
# title          0
# total_gross    0
# genres         6
# popularity     0
# dtype: int64

# %%
test_data.head(30)
# Out:
#                                           title  total_gross  \
# 0                        Avengers: Infinity War   2048300000
# 1                                Jurassic World   1671700000
# 2                                     Furious 7   1516000000
# 3                       Avengers: Age of Ultron   1405400000
# 5                                 Black Panther   1347000000
# 7                      Star Wars: The Last Jedi   1332600000
# 8                Jurassic World: Fallen Kingdom   1309500000
# 14                                       Frozen   1276400000
# 15                                Incredibles 2   1242800000
# 16                      The Fate of the Furious   1236000000
# 17                                   Iron Man 3   1214800000
# 18                                      Minions   1159400000
# 19                   Captain America: Civil War   1153300000
# 20                                      Aquaman   1147800000
# 21               Transformers: Dark of the Moon   1123800000
# 22                                      Skyfall   1108600000
# 23              Transformers: Age of Extinction   1104000000
# 24                        The Dark Knight Rises   1084900000
# 25                                  Toy Story 3   1067000000
# 27                 Rogue One: A Star Wars Story   1056100000
# 28  Pirates of the Caribbean: On Stranger Tides   1045700000
# 29                              Despicable Me 3   1034800000
# 30                                 Finding Dory   1028600000
# 31                                     Zootopia   1023800000
# 32            The Hobbit: An Unexpected Journey   1021100000
# 33                              Despicable Me 2    970800000
# 35               Jumanji: Welcome to the Jungle    962100000
# 36          The Hobbit: The Desolation of Smaug    958399999
# 37    The Hobbit: The Battle of the Five Armies    956000000
# 38                            Bohemian Rhapsody    903600000
#
#                         genres  popularity
# 0      Action,Adventure,Sci-Fi      80.773
# 1      Action,Adventure,Sci-Fi      20.709
# 2        Action,Crime,Thriller      20.396
# 3      Action,Adventure,Sci-Fi      44.383
# 5      Action,Adventure,Sci-Fi      44.140
# 7     Action,Adventure,Fantasy      34.293
# 8      Action,Adventure,Sci-Fi      34.958
# 14  Adventure,Animation,Comedy      26.183
# 15  Action,Adventure,Animation      36.286
# 16       Action,Crime,Thriller      28.668
# 17     Action,Adventure,Sci-Fi      32.093
# 18  Adventure,Animation,Comedy       9.338
# 19     Action,Adventure,Sci-Fi      39.137
# 20    Action,Adventure,Fantasy      38.102
# 21     Action,Adventure,Sci-Fi       5.339
# 22   Action,Adventure,Thriller      19.270
# 23     Action,Adventure,Sci-Fi      20.961
# 24             Action,Thriller      26.220
# 25  Adventure,Animation,Comedy      24.445
# 27     Action,Adventure,Sci-Fi      21.401
# 28    Action,Adventure,Fantasy      30.579
# 29  Adventure,Animation,Comedy      16.407
# 30  Adventure,Animation,Comedy      15.393
# 31  Adventure,Animation,Comedy      27.549
# 32    Adventure,Family,Fantasy      26.939
# 33  Adventure,Animation,Comedy      19.014
# 35     Action,Adventure,Comedy      20.395
# 36           Adventure,Fantasy      21.275
# 37           Adventure,Fantasy      53.783
# 38       Biography,Drama,Music      37.197

# %%
for x in combined_data.nlargest(100, 'popularity'):
