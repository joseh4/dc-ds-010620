# %% [markdown]
# # Pandas Tips & Review
# ### As a data scientist, you will be utilizing the pandas library in various ways to solve some of the world's most pressing issues
#
#
# ### Here are some useful pandas methods to manipulate dataframes to do and show us whatever we want!

# %% [markdown]
# ![Alt Text](https://media.giphy.com/media/FYnYcQoFmlPeU/giphy.gif)

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #### Let's use the merge function from pandas to combine two dataframes together

# %%
df1 = pd.read_csv('heart.csv')
df1.tail()
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0

# %%
df2 = pd.DataFrame(np.random.randint(0,100,size=(303,3)), columns=['B','C','D'])

# %%
df3 = pd.merge(df1,df2, on=df1.index)
df3
# Out:
#      key_0  age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  \
# 0        0   63    1   3       145   233    1        0      150      0
# 1        1   37    1   2       130   250    0        1      187      0
# 2        2   41    0   1       130   204    0        0      172      0
# 3        3   56    1   1       120   236    0        1      178      0
# 4        4   57    0   0       120   354    0        1      163      1
# ..     ...  ...  ...  ..       ...   ...  ...      ...      ...    ...
# 298    298   57    0   0       140   241    0        1      123      1
# 299    299   45    1   3       110   264    0        1      132      0
# 300    300   68    1   0       144   193    1        1      141      0
# 301    301   57    1   0       130   131    0        1      115      1
# 302    302   57    0   1       130   236    0        0      174      0
#
#      oldpeak  slope  ca  thal  target   B   C   D
# 0        2.3      0   0     1       1  52  67  97
# 1        3.5      0   0     2       1  95  58  72
# 2        1.4      2   0     2       1  89  52  87
# 3        0.8      2   0     2       1  47  51  80
# 4        0.6      2   0     2       1  72  83  29
# ..       ...    ...  ..   ...     ...  ..  ..  ..
# 298      0.2      1   0     3       0  23   5  34
# 299      1.2      1   0     3       0  83   7  43
# 300      3.4      1   2     3       0  19  83   6
# 301      1.2      1   1     3       0  81  52  34
# 302      0.0      1   1     2       0  31  37  57
#
# [303 rows x 18 columns]

# %% [markdown]
# Answer Below

# %%
df3 = pd.merge(df1,df2, on=df1.index)

# %%
df3

# %% [markdown]
# #### What if we wanted to simply add on a few relevant columns with data to our dataframe? (Hint: Use Concat)

# %%
lab_df = pd.DataFrame(np.random.randint(0,100,size=(303,3)), columns=['Chemical_A','Chemical_B','Chemical_C'])

# %%
concat_df = pd.concat([df2,lab_df], axis=1)
concat_df
# Out:
#       B   C   D  Chemical_A  Chemical_B  Chemical_C
# 0    52  67  97          80          29          34
# 1    95  58  72          41          44          22
# 2    89  52  87          81          65          69
# 3    47  51  80          37          76          50
# 4    72  83  29          28          78          11
# ..   ..  ..  ..         ...         ...         ...
# 298  23   5  34          10          80          35
# 299  83   7  43          26          23          59
# 300  19  83   6          91          25          66
# 301  81  52  34          99          67          29
# 302  31  37  57          83          74          86
#
# [303 rows x 6 columns]

# %% [markdown]
# Answer Below

# %%
concated_df = pd.concat([df2,lab_df],axis=1)

# %%
concated_df

# %% [markdown]
# ### So what exactly does the join method do? Use the join method utilizing the 'left join'

# %%
joined_df = df1.join(df2, on=df1.index, how='left')
joined_df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target   B   C   D
# 0        0   0     1       1  52  67  97
# 1        0   0     2       1  95  58  72
# 2        2   0     2       1  89  52  87
# 3        2   0     2       1  47  51  80
# 4        2   0     2       1  72  83  29
# ..     ...  ..   ...     ...  ..  ..  ..
# 298      1   0     3       0  23   5  34
# 299      1   0     3       0  83   7  43
# 300      1   2     3       0  19  83   6
# 301      1   1     3       0  81  52  34
# 302      1   1     2       0  31  37  57
#
# [303 rows x 17 columns]

# %% [markdown]
# Answer Below

# %%
joined_df = df1.join(df2, on=df1.index,how='left')

# %%
joined_df

# %% [markdown]
# ## Now let's talk about .loc vs .iloc

# %% [markdown]
# The Pandas loc indexer can be used with DataFrames for two different use cases:
#
# a.) Selecting rows by label/index
# b.) Selecting rows with a boolean / conditional lookup

# %% [markdown]
# a.) Selecting rows by label/index

# %%
# Select rows with index values '0' through '100', with all columns between 'age' and 'chol'
joined_df.loc[0:100, 'age':'chol']
# Out:
#      age  sex  cp  trestbps  chol
# 0     63    1   3       145   233
# 1     37    1   2       130   250
# 2     41    0   1       130   204
# 3     56    1   1       120   236
# 4     57    0   0       120   354
# ..   ...  ...  ..       ...   ...
# 96    62    0   0       140   394
# 97    52    1   0       108   233
# 98    43    1   2       130   315
# 99    53    1   2       130   246
# 100   42    1   3       148   244
#
# [101 rows x 5 columns]

# %% [markdown]
# >Notice below .loc[487] does not grab row 487, but rather the index of 487

# %%
joined_df.loc[300]
# Out:
# age          68.0
# sex           1.0
# cp            0.0
# trestbps    144.0
# chol        193.0
# fbs           1.0
# restecg       1.0
# thalach     141.0
# exang         0.0
# oldpeak       3.4
# slope         1.0
# ca            2.0
# thal          3.0
# target        0.0
# B            19.0
# C            83.0
# D             6.0
# Name: 300, dtype: float64

# %% [markdown]
# b.) Selecting rows with a boolean / conditional lookup

# %%
# select rows with indexes between 100 and 200, and just return 'age' and 'cp' columns
joined_df.loc[(joined_df.index > 100) & (joined_df.index <= 200), ['age', 'cp']]
# Out:
#      age  cp
# 101   59   3
# 102   63   1
# 103   42   2
# 104   50   2
# 105   68   2
# ..   ...  ..
# 196   46   2
# 197   67   0
# 198   62   0
# 199   65   0
# 200   44   0
#
# [100 rows x 2 columns]

# %% [markdown]
# The iloc indexer for Pandas Dataframe is used for integer-location based indexing / selection by position.

# %% [markdown]
# ##### Use .iloc to grab specific rows

# %% [markdown]
# First 4 rows

# %%
joined_df.iloc[0:4]
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
#
#    ca  thal  target   B   C   D
# 0   0     1       1  52  67  97
# 1   0     2       1  95  58  72
# 2   0     2       1  89  52  87
# 3   0     2       1  47  51  80

# %%
joined_df.iloc[5:18]
# Out:
#     age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 5    57    1   0       140   192    0        1      148      0      0.4
# 6    56    0   1       140   294    0        0      153      0      1.3
# 7    44    1   1       120   263    0        1      173      0      0.0
# 8    52    1   2       172   199    1        1      162      0      0.5
# 9    57    1   2       150   168    0        1      174      0      1.6
# 10   54    1   0       140   239    0        1      160      0      1.2
# 11   48    0   2       130   275    0        1      139      0      0.2
# 12   49    1   1       130   266    0        1      171      0      0.6
# 13   64    1   3       110   211    0        0      144      1      1.8
# 14   58    0   3       150   283    1        0      162      0      1.0
# 15   50    0   2       120   219    0        1      158      0      1.6
# 16   58    0   2       120   340    0        1      172      0      0.0
# 17   66    0   3       150   226    0        1      114      0      2.6
#
#     slope  ca  thal  target   B   C   D
# 5       1   0     1       1  68  24  65
# 6       1   0     2       1  69  63  46
# 7       2   0     3       1  43  19  65
# 8       2   0     3       1  86  60  32
# 9       2   0     2       1  49  42  70
# 10      2   0     2       1  33  85  41
# 11      2   0     2       1  73  84  76
# 12      2   0     2       1  99  13  38
# 13      1   0     2       1  58  41  95
# 14      2   0     2       1  52  55  63
# 15      1   0     2       1  18  56  86
# 16      2   0     2       1  85  62   9
# 17      0   0     2       1  84  38  38

# %% [markdown]
# First 3 columns

# %%
joined_df.iloc[:,0:3]
# Out:
#      age  sex  cp
# 0     63    1   3
# 1     37    1   2
# 2     41    0   1
# 3     56    1   1
# 4     57    0   0
# ..   ...  ...  ..
# 298   57    0   0
# 299   45    1   3
# 300   68    1   0
# 301   57    1   0
# 302   57    0   1
#
# [303 rows x 3 columns]

# %% [markdown]
# Or grab rows (0,3,6,24) from columns (0,5,6)

# %%
joined_df.iloc[[0,3,6,24], [0,5,6]]
# Out:
#     age  fbs  restecg
# 0    63    1        0
# 3    56    0        1
# 6    56    0        0
# 24   40    0        1

# %% [markdown]
# # Ways to utilize lambda functions
# #### .map(), .apply(), .applymap()

# %% [markdown]
# The map() method only works on pandas series

# %% [markdown]
# The apply () method works on panda series and data frames

# %% [markdown]
# The applymap() method works on the entire pandas data frame where the input function is applied to every element individually. In other words, applymap() is appy() + map()!

# %% [markdown]
# a series is anothe name for a column. If you call on a column, your asking for the series

# %%
df = pd.read_csv('heart.csv')
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
new_df = df.age.map(lambda x: x * 10)
type(new_df)
# Out:
# pandas.core.series.Series

# %%
super_df = df.age.apply(lambda x: x * 10)
type(super_df)
super_df
# Out:
# 0      630
# 1      370
# 2      410
# 3      560
# 4      570
#       ...
# 298    570
# 299    450
# 300    680
# 301    570
# 302    570
# Name: age, Length: 303, dtype: int64

# %%
ultra_df = df.age.applymap(lmabda x: x* 10)
# Out:
#   File "<ipython-input-75-3f1a3d712aa8>", line 1
#     ultra_df = df.age.applymap(lmabda x: x* 10)
#                                       ^
# SyntaxError: invalid syntax

# %% [markdown]
# #### How else could we manipulate the 'age' column?

# %%
my_df = df.age.mean()
my_df
# Out:
# 54.366336633663366

# %%
my_new_df = df.age.map(lambda x: x+5)
my_new_df.head()
# Out:
# 0    68
# 1    42
# 2    46
# 3    61
# 4    62
# Name: age, dtype: int64

# %% [markdown]
# Do these two dataframes equal the same thing?

# %%
new_ultra_df = df.applymap(lambda x: x*10)
new_ultra_df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0    630   10  30      1450  2330   10        0     1500      0     23.0
# 1    370   10  20      1300  2500    0       10     1870      0     35.0
# 2    410    0  10      1300  2040    0        0     1720      0     14.0
# 3    560   10  10      1200  2360    0       10     1780      0      8.0
# 4    570    0   0      1200  3540    0       10     1630     10      6.0
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298  570    0   0      1400  2410    0       10     1230     10      2.0
# 299  450   10  30      1100  2640    0       10     1320      0     12.0
# 300  680   10   0      1440  1930   10       10     1410      0     34.0
# 301  570   10   0      1300  1310    0       10     1150     10     12.0
# 302  570    0  10      1300  2360    0        0     1740      0      0.0
#
#      slope  ca  thal  target
# 0        0   0    10      10
# 1        0   0    20      10
# 2       20   0    20      10
# 3       20   0    20      10
# 4       20   0    20      10
# ..     ...  ..   ...     ...
# 298     10   0    30       0
# 299     10   0    30       0
# 300     10  20    30       0
# 301     10  10    30       0
# 302     10  10    20       0
#
# [303 rows x 14 columns]

# %%
(new_df == super_df).value_counts()
# Out:
# True    303
# Name: age, dtype: int64

# %%
apply_df = df.applymap(lambda x: x*10)

# %%
apply_df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0    630   10  30      1450  2330   10        0     1500      0     23.0
# 1    370   10  20      1300  2500    0       10     1870      0     35.0
# 2    410    0  10      1300  2040    0        0     1720      0     14.0
# 3    560   10  10      1200  2360    0       10     1780      0      8.0
# 4    570    0   0      1200  3540    0       10     1630     10      6.0
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298  570    0   0      1400  2410    0       10     1230     10      2.0
# 299  450   10  30      1100  2640    0       10     1320      0     12.0
# 300  680   10   0      1440  1930   10       10     1410      0     34.0
# 301  570   10   0      1300  1310    0       10     1150     10     12.0
# 302  570    0  10      1300  2360    0        0     1740      0      0.0
#
#      slope  ca  thal  target
# 0        0   0    10      10
# 1        0   0    20      10
# 2       20   0    20      10
# 3       20   0    20      10
# 4       20   0    20      10
# ..     ...  ..   ...     ...
# 298     10   0    30       0
# 299     10   0    30       0
# 300     10  20    30       0
# 301     10  10    30       0
# 302     10  10    20       0
#
# [303 rows x 14 columns]

# %%
# !pip install faker
# Out:
# Requirement already satisfied: faker in /Users/joseph/opt/anaconda3/lib/python3.7/site-packages (4.0.0)
# Requirement already satisfied: python-dateutil>=2.4 in /Users/joseph/opt/anaconda3/lib/python3.7/site-packages (from faker) (2.8.0)
# Requirement already satisfied: text-unidecode==1.3 in /Users/joseph/opt/anaconda3/lib/python3.7/site-packages (from faker) (1.3)
# Requirement already satisfied: six>=1.5 in /Users/joseph/opt/anaconda3/lib/python3.7/site-packages (from python-dateutil>=2.4->faker) (1.12.0)

# %%
from faker import Faker
fake = Faker()
fake.name()
# Out:
# 'Amy Oconnell'

# %% [markdown]
# Let's generate a column of names

# %%
df['name'] = [fake.name() for x in range(303)]
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target              name
# 0   0     1       1    Courtney Reese
# 1   0     2       1   Courtney Nguyen
# 2   0     2       1      Karen Benson
# 3   0     2       1   Katherine Lloyd
# 4   0     2       1  Katrina Hatfield

# %%
df.name = df.name.map(lambda x: x.replace(" ",'_'))
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target              name
# 0   0     1       1    Courtney_Reese
# 1   0     2       1   Courtney_Nguyen
# 2   0     2       1      Karen_Benson
# 3   0     2       1   Katherine_Lloyd
# 4   0     2       1  Katrina_Hatfield

# %% [markdown]
# ## BONUS:
# ##### Can you grab the row with info on Brent Jones?

# %%
courtney_reese = df.loc[df.name=='Courtney_Reese']
brent_jones = df.loc[df.name=='Brent_Jones']
courtney_reese #Will result in a result
brent_jones # will not result in a result because there is no brent jones
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
#
#    ca  thal  target            name
# 0   0     1       1  Courtney_Reese

# %% [markdown]
# Answer Below

# %%
brent_jones = df.loc[df['name'] == 'Brent_Jones']
