# %%
import pandas as pd

# %%
df = pd.read_csv('OnlineArrestData1980-2018.csv')

# %%
df.head(20)
# Out:
#     YEAR GENDER   RACE AGE_GROUP               COUNTY  VIOLENT  PROPERTY  \
# 0   1980   Male  Black  Under 18       Alameda County      505      1351
# 1   1980   Male  Black  Under 18         Butte County        3         5
# 2   1980   Male  Black  Under 18     Calaveras County        0         0
# 3   1980   Male  Black  Under 18  Contra Costa County      116       446
# 4   1980   Male  Black  Under 18     El Dorado County        0         1
# 5   1980   Male  Black  Under 18        Fresno County      123       307
# 6   1980   Male  Black  Under 18         Glenn County        0         0
# 7   1980   Male  Black  Under 18      Humboldt County        0         1
# 8   1980   Male  Black  Under 18      Imperial County        6         4
# 9   1980   Male  Black  Under 18          Inyo County        0         0
# 10  1980   Male  Black  Under 18          Kern County       57       177
# 11  1980   Male  Black  Under 18         Kings County        6        26
# ...

# %%
alameda = df.loc[df['COUNTY']=='Alameda County']

# %%
alameda = al.loc[al['YEAR'] == 2018]

# %%
alameda
# Out:
#        YEAR  GENDER      RACE    AGE_GROUP          COUNTY  VIOLENT  PROPERTY  \
# 92387  2018    Male     Black     Under 18  Alameda County      218       132
# 92435  2018    Male     Black     18 to 19  Alameda County       95        51
# 92485  2018    Male     Black     20 to 29  Alameda County      432       275
# 92542  2018    Male     Black     30 to 39  Alameda County      319       232
# 92599  2018    Male     Black     40 to 69  Alameda County      387       323
# 92656  2018    Male     Black  70 and over  Alameda County        5         3
# 92687  2018    Male  Hispanic     Under 18  Alameda County       86        58
# 92739  2018    Male  Hispanic     18 to 19  Alameda County       69        44
# 92796  2018    Male  Hispanic     20 to 29  Alameda County      310       210
# 92854  2018    Male  Hispanic     30 to 39  Alameda County      192       164
# 92911  2018    Male  Hispanic     40 to 69  Alameda County      171       121
# ...

# %%
la = df.loc[df['COUNTY']=='Los Angeles County']

# %%
la = la.loc[la['YEAR']==2018]

# %%
la
# Out:
#        YEAR  GENDER      RACE    AGE_GROUP              COUNTY  VIOLENT  \
# 92401  2018    Male     Black     Under 18  Los Angeles County      571
# 92450  2018    Male     Black     18 to 19  Los Angeles County      426
# 92503  2018    Male     Black     20 to 29  Los Angeles County     2184
# 92560  2018    Male     Black     30 to 39  Los Angeles County     1418
# 92617  2018    Male     Black     40 to 69  Los Angeles County     1832
# 92662  2018    Male     Black  70 and over  Los Angeles County       52
# 92704  2018    Male  Hispanic     Under 18  Los Angeles County      799
# 92757  2018    Male  Hispanic     18 to 19  Los Angeles County      714
# 92814  2018    Male  Hispanic     20 to 29  Los Angeles County     4625
# 92872  2018    Male  Hispanic     30 to 39  Los Angeles County     3190
# 92928  2018    Male  Hispanic     40 to 69  Los Angeles County     2344
# 92982  2018    Male  Hispanic  70 and over  Los Angeles County       40
# ...

# %%
la
# Out:
#        YEAR  GENDER      RACE AGE_GROUP              COUNTY  VIOLENT  \
# 92503  2018    Male     Black  20 to 29  Los Angeles County     2184
# 92560  2018    Male     Black  30 to 39  Los Angeles County     1418
# 92617  2018    Male     Black  40 to 69  Los Angeles County     1832
# 92814  2018    Male  Hispanic  20 to 29  Los Angeles County     4625
# 92872  2018    Male  Hispanic  30 to 39  Los Angeles County     3190
# 92928  2018    Male  Hispanic  40 to 69  Los Angeles County     2344
# 93140  2018    Male     Other  20 to 29  Los Angeles County      378
# 93198  2018    Male     Other  30 to 39  Los Angeles County      359
# 93256  2018    Male     Other  40 to 69  Los Angeles County      420
# 93473  2018    Male     White  20 to 29  Los Angeles County      788
# 93531  2018    Male     White  30 to 39  Los Angeles County      881
# 93589  2018    Male     White  40 to 69  Los Angeles County     1263
# 93785  2018  Female     Black  20 to 29  Los Angeles County      788
# ...

# %%
#I needed to add all the crime together and di not need the year to add to my total. I know i'm in the year 2018 
# as I sorted it above.
crime_total_males = la.drop(columns = ['YEAR', 'VIOLENT', 'PROPERTY', 'F_DRUGOFF', 'F_SEXOFF', 'F_ALLOTHER'])

# %%
crime_total_males[crime_total_males.GENDER != 'Female']
# Out:
#       GENDER      RACE    AGE_GROUP              COUNTY  F_TOTAL  M_TOTAL  \
# 92401   Male     Black     Under 18  Los Angeles County     1121      554
# 92450   Male     Black     18 to 19  Los Angeles County      984      555
# 92503   Male     Black     20 to 29  Los Angeles County     5373     7277
# 92560   Male     Black     30 to 39  Los Angeles County     3573     6305
# 92617   Male     Black     40 to 69  Los Angeles County     4039     9879
# 92662   Male     Black  70 and over  Los Angeles County       73      197
# 92704   Male  Hispanic     Under 18  Los Angeles County     1825     1683
# 92757   Male  Hispanic     18 to 19  Los Angeles County     1934     2482
# 92814   Male  Hispanic     20 to 29  Los Angeles County    12950    28409
# 92872   Male  Hispanic     30 to 39  Los Angeles County     8846    21014
# 92928   Male  Hispanic     40 to 69  Los Angeles County     6161    19178
# 92982   Male  Hispanic  70 and over  Los Angeles County       73      210
# ...

# %%
crime_total_males.drop(columns = 'AGE_GROUP', inplace=True)

# %%
crime_total_males
# Out:
#        GENDER      RACE              COUNTY  F_TOTAL  M_TOTAL  S_TOTAL
# 92401    Male     Black  Los Angeles County     1121      554       23
# 92450    Male     Black  Los Angeles County      984      555        0
# 92503    Male     Black  Los Angeles County     5373     7277        0
# 92560    Male     Black  Los Angeles County     3573     6305        0
# 92617    Male     Black  Los Angeles County     4039     9879        0
# 92662    Male     Black  Los Angeles County       73      197        0
# 92704    Male  Hispanic  Los Angeles County     1825     1683      181
# 92757    Male  Hispanic  Los Angeles County     1934     2482        0
# 92814    Male  Hispanic  Los Angeles County    12950    28409        0
# 92872    Male  Hispanic  Los Angeles County     8846    21014        0
# 92928    Male  Hispanic  Los Angeles County     6161    19178        0
# 92982    Male  Hispanic  Los Angeles County       73      210        0
# ...

# %%
ctm = crime_total_males.sum(axis=1)

# %%
ctm
# Out:
# 92401     1698
# 92450     1539
# 92503    12650
# 92560     9878
# 92617    13918
# 92662      270
# 92704     3689
# 92757     4416
# 92814    41359
# 92872    29860
# 92928    25339
# 92982      283
# 93032      217
# 93086      271
# 93140     2958
# 93198     2898
# 93256     3227
# 93309      130
# 93361      523
# 93416      666
# 93473     9182
# 93531    10347
# 93589    16344
# 93646      380
# 93695      624
# 93740      775
# 93785     5206
# 93837     3047
# 93890     3384
# 93929       53
# 93964     1142
# 94014     1161
# 94066    10323
# 94122     6971
# 94178     5233
# 94225       30
# 94263       71
# 94309      111
# 94359      989
# 94417      876
# 94474      978
# 94518       36
# 94556      169
# 94611      310
# 94666     3753
# 94724     3905
# 94782     4935
# 94837       75
# dtype: int64

# %%
#ctm is crime total for males. ctm is a pandas series
ctm.sum()
# Out:
# 246199

# %%
crime_total_females = crime_total_males[crime_total_males.GENDER != 'Male']

# %%
crime_total_females
# Out:
#        GENDER      RACE              COUNTY  F_TOTAL  M_TOTAL  S_TOTAL
# 93695  Female     Black  Los Angeles County      262      353        9
# 93740  Female     Black  Los Angeles County      259      516        0
# 93785  Female     Black  Los Angeles County     1585     3621        0
# 93837  Female     Black  Los Angeles County      961     2086        0
# 93890  Female     Black  Los Angeles County      940     2444        0
# 93929  Female     Black  Los Angeles County        4       49        0
# 93964  Female  Hispanic  Los Angeles County      370      697       75
# 94014  Female  Hispanic  Los Angeles County      347      814        0
# 94066  Female  Hispanic  Los Angeles County     3238     7085        0
# 94122  Female  Hispanic  Los Angeles County     1996     4975        0
# 94178  Female  Hispanic  Los Angeles County     1168     4065        0
# 94225  Female  Hispanic  Los Angeles County        5       25        0
# ...

# %%
ctf = crime_total_females.sum(axis=1)

# %%
ctf.sum()
# Out:
# 54157

# %%
LA_arrest_toal = ctf.sum() + ctm.sum()

# %%
LA_arrest_toal
# Out:
# 300356

# %%
10**7
# Out:
# 10000000

# %%
LA_arrest_toal / 10105518
# Out:
# 0.02972197961549324
